# %%
first = int(input())
second = int(input())
third = int(input())
forth = int(input())

totalSec = first + second + third + forth
x = totalSec//60
y = totalSec%60
print(x)
print(y)
# Out:
#  1
#  15
#  46
#  660
# 12
# 2
