# %% [markdown]
# King, Queen, Rook, Bishop, Knight, Pawn = map(int, input().split())
# King = (King - 1)*-1
# Queen = (Queen - 1)*-1
# Rook = (Rook - 2)*-1
# Bishop = (Bishop - 2)*-1
# Knight = (Knight - 2)*-1
# Pawn = (Pawn - 8)*-1
#
# print(King, Queen, Rook, Bishop, Knight, Pawn)

# %%
King, Queen, Rook, Bishop, Knight, Pawn = map(int, input().split())
King = (King - 1)*-1
Queen = (Queen - 1)*-1
Rook = (Rook - 2)*-1
Bishop = (Bishop - 2)*-1
Knight = (Knight - 2)*-1
Pawn = (Pawn - 8)*-1
  
print(King, Queen, Rook, Bishop, Knight, Pawn)
# Out:
#  0 1 2 2 2 7
# 1 0 0 0 0 1
