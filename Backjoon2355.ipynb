# %% [markdown]
# num1, num2 = map(int, input().split())
# if num1 >= num2:
#     print((num1*(num1+1)/2 - num2*(num2+1)/2)+num2)
# else:
#     print((num2*(num2+1)/2 - num1*(num1+1)/2)+num1)

# %%
num1, num2 = map(int, input().split())
if num1 >= num2:
    num = ((num1*(num1+1)//2 - num2*(num2+1)//2)+num2)
else:
    num = ((num2*(num2+1)//2 - num1*(num1+1)//2)+num1)
print(num)
# Out:
#  1 4
# 10
