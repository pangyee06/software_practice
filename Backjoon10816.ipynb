# %%
n = int(input())
cards = list(map(int, input().split()))

counter = {}
for x in cards:
    counter[x] = counter.get(x, 0) + 1

m = int(input())
queries = list(map(int, input().split()))

print(*[counter.get(x, 0) for x in queries])
