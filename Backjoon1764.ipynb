# %%
n, m = map(int, input().split())
never_heard = {input().strip()for_in range(n)}
never_seen = {input().strip()for_in range(m)}

result = sorted(never_heard & never_seen)
print(len(result))
for name in result:
    print(name)
